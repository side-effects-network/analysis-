# %% [markdown]
#     Reads polypharmacy side effects data from a CSV file into a pandas DataFrame
#
#     Parameters:
#     file_path (str): Path to the CSV file
#
#     Returns:
#     pandas.DataFrame: DataFrame with polypharmacy data

# %%
import pandas as pd


file_path = r"ChChSe-Decagon_polypharmacy.csv"

columns = ['STITCH_1', 'STITCH_2', 'Polypharmacy_Side_Effect', 'Side_Effect_Name']

pairs_df = pd.read_csv(file_path, names=columns)

pairs_df = pairs_df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

pairs_df.head(10)
# Out:
#        STITCH_1      STITCH_2 Polypharmacy_Side_Effect  \
# 0  CID000002173  CID000003345                 C0151714
# 1  CID000002173  CID000003345                 C0035344
# 2  CID000002173  CID000003345                 C0004144
# 3  CID000002173  CID000003345                 C0002063
# 4  CID000002173  CID000003345                 C0004604
# 5  CID000002173  CID000003345                 C0034063
# 6  CID000002173  CID000003345                 C0085631
# 7  CID000002173  CID000003345                 C0013384
# 8  CID000002173  CID000003345                 C0001122
# 9  CID000002173  CID000003345                 C0034150
#
#              Side_Effect_Name
# 0             hypermagnesemia
# 1  retinopathy of prematurity
# 2                 atelectasis
# 3                   alkalosis
# 4                   Back Ache
# 5                  lung edema
# 6                    agitated
# 7          abnormal movements
# 8                    Acidosis
# 9                    peliosis

# %% [markdown]
# isolationg just the side-effects

# %%
side_effects_df = pairs_df[['Polypharmacy_Side_Effect', 'Side_Effect_Name']]
    
    # Save last 2 rows to a new CSV file

last_column = side_effects_df.columns[-1]

# Convert the last column to uppercase
side_effects_df[last_column] = side_effects_df[last_column].str.upper()
# Out:
# C:\Users\pietr\AppData\Local\Temp\ipykernel_10536\1340648040.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   side_effects_df[last_column] = side_effects_df[last_column].str.upper()
#   Polypharmacy_Side_Effect            Side_Effect_Name
# 0                 C0151714             HYPERMAGNESEMIA
# 1                 C0035344  RETINOPATHY OF PREMATURITY
# 2                 C0004144                 ATELECTASIS
# 3                 C0002063                   ALKALOSIS
# 4                 C0004604                   BACK ACHE
# 5                 C0034063                  LUNG EDEMA
# 6                 C0085631                    AGITATED
# 7                 C0013384          ABNORMAL MOVEMENTS
# 8                 C0001122                    ACIDOSIS
# 9                 C0034150                    PELIOSIS

# %% [markdown]
# pandas for the ranking of side-effects

# %%
se_ranking_df = pd.read_excel('jmir_v17i3e80_app4.xlsx')
se_ranking_df.to_csv('ranking.csv', index=False)

# %% [markdown]
# merging side-effects and rankings

# %%
merged_df = side_effects_df.merge(se_ranking_df, left_on="Side_Effect_Name", right_on="Name", how="left")

# Replace NaN values in 'Rank score' with "unknown"
merged_df["Rank score"] = merged_df["Rank score"].fillna("unknown")
merged_df.iloc[:, -1] = merged_df.iloc[:, -1].fillna("unknown")
merged_df.drop(columns=['Name'], inplace=True)
# Out:
# C:\Users\pietr\AppData\Local\Temp\ipykernel_10536\2709431937.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0            unknown
# 1          11.826728
# 2          19.910377
# 3           1.995541
# 4            unknown
#              ...
# 4649436      unknown
# 4649437     7.575071
# 4649438      unknown
# 4649439     8.170583
# 4649440      unknown
# Name: Rank Stdev (% out 2929), Length: 4649441, dtype: object' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   merged_df.iloc[:, -1] = merged_df.iloc[:, -1].fillna("unknown")
#    Polypharmacy_Side_Effect                        Side_Effect_Name  \
# 0                  C0151714                         HYPERMAGNESEMIA
# 1                  C0035344              RETINOPATHY OF PREMATURITY
# 2                  C0004144                             ATELECTASIS
# 3                  C0002063                               ALKALOSIS
# 4                  C0004604                               BACK ACHE
# 5                  C0034063                              LUNG EDEMA
# 6                  C0085631                                AGITATED
# 7                  C0013384                      ABNORMAL MOVEMENTS
# 8                  C0001122                                ACIDOSIS
# 9                  C0034150                                PELIOSIS
# 10                 C0038000                       RUPTURE OF SPLEEN
# 11                 C0003578                                   APNEA
# 12                 C0013182                   DRUG HYPERSENSITIVITY
# 13                 C0016204                              FLATULENCE
# 14                 C0242429                          PAIN IN THROAT
# 15                 C0020517                               ALLERGIES
# 16                 C0040034                        THROMBOCYTOPENIA
# 17                 C0428977                             BRADYCARDIA
# 18                 C0235896                       LUNG INFILTRATION
# 19                 C0019080                                BLEEDING
# 20                 C0158986                  HYPOGLYCAEMIA NEONATAL
# 21                 C0236124            GASTROINTESTINAL OBSTRUCTION
# 22                 C0020456                          HYPERGLYCAEMIA
# 23                 C0031154                             PERITONITIS
# 24                 C0020615                           HYPOGLYCAEMIA
# 25                 C0000731                    ABDOMINAL DISTENSION
# 26                 C0018790                                ASYSTOLE
# 27                 C0007785                        CEREBRAL INFARCT
# 28                 C0242184                                 HYPOXIA
# 29                 C0013404                    DIFFICULTY BREATHING
# 30                 C0020672              DECREASED BODY TEMPERATURE
# 31                 C0030446                          ADYNAMIC ILEUS
# 32                 C0243026                                  SEPSIS
# 33                 C0151723                         HYPOMAGNESAEMIA
# 34                 C0035220  NEONATAL RESPIRATORY DISTRESS SYNDROME
# 35                 C0035222     ACUTE RESPIRATORY DISTRESS SYNDROME
# 36                 C0023798                                  LIPOMA
# 37                 C0030790                        PELVIC INFECTION
# 38                 C0003611                            APPENDECTOMY
# 39                 C0016199                              FLANK PAIN
# 40                 C0032326                            PNEUMOTHORAX
# 41                 C0003615                            APPENDICITIS
# 42                 C0038379                              STRABISMUS
# 43                 C0020598                 BLOOD CALCIUM DECREASED
# 44                 C1145670                     RESPIRATORY FAILURE
# 45                 C0020542                  PULMONARY HYPERTENSION
# 46                 C0020440                             HYPERCAPNIA
# 47                 C0021845                  INTESTINAL PERFORATION
# 48                 C0023518                            LEUCOCYTOSIS
# 49                 C0024115                           DISORDER LUNG
#
#    Rank score Rank Stdev (% out 2929)
# 0     unknown                 unknown
# 1    0.489986               11.826728
# 2    0.693081               19.910377
# 3    0.505357                1.995541
# 4     unknown                 unknown
# 5     unknown                 unknown
# 6     unknown                 unknown
# 7     unknown                 unknown
# 8     0.43851                8.379133
# 9     unknown                 unknown
# 10    unknown                 unknown
# 11    unknown                 unknown
# 12    0.52759               10.955188
# 13   0.221206               17.796201
# 14    unknown                 unknown
# 15    unknown                 unknown
# 16   0.578966               32.291414
# 17   0.507201                9.727248
# 18   0.547467               17.580052
# 19    unknown                 unknown
# 20    0.51558                6.951293
# 21   0.671746               22.398449
# 22    0.44743               12.969218
# 23   0.453942               11.893462
# 24   0.415011                7.583146
# 25    0.44412                 1.78234
# 26    unknown                 unknown
# 27    unknown                 unknown
# 28   0.701153               18.404887
# 29    unknown                 unknown
# 30    unknown                 unknown
# 31    unknown                 unknown
# 32   0.707858               11.082763
# 33   0.438578                4.913982
# 34    unknown                 unknown
# 35   0.720924               10.609355
# 36   0.463404               23.844799
# 37   0.705199                4.865631
# 38    unknown                 unknown
# 39   0.306166               13.470668
# 40   0.608705                3.674334
# 41   0.591927               22.531193
# 42   0.335883               22.452211
# 43    unknown                 unknown
# 44   0.856541                4.597095
# 45   0.584573               27.009329
# 46   0.562558               19.021888
# 47   0.786244                5.533251
# 48    unknown                 unknown
# 49    unknown                 unknown

# %% [markdown]
# merging the dataframes for drgs pairs, side effects and rankinkgs

# %%
columns_to_add = pairs_df[["STITCH_1","STITCH_2"]]

final_merged_df = pd.concat([columns_to_add, merged_df ], axis=1)
final_merged_df.head(10)
# Out:
#        STITCH_1      STITCH_2 Polypharmacy_Side_Effect  \
# 0  CID000002173  CID000003345                 C0151714
# 1  CID000002173  CID000003345                 C0035344
# 2  CID000002173  CID000003345                 C0004144
# 3  CID000002173  CID000003345                 C0002063
# 4  CID000002173  CID000003345                 C0004604
# 5  CID000002173  CID000003345                 C0034063
# 6  CID000002173  CID000003345                 C0085631
# 7  CID000002173  CID000003345                 C0013384
# 8  CID000002173  CID000003345                 C0001122
# 9  CID000002173  CID000003345                 C0034150
#
#              Side_Effect_Name Rank score Rank Stdev (% out 2929)
# 0             HYPERMAGNESEMIA    unknown                 unknown
# 1  RETINOPATHY OF PREMATURITY   0.489986               11.826728
# 2                 ATELECTASIS   0.693081               19.910377
# 3                   ALKALOSIS   0.505357                1.995541
# 4                   BACK ACHE    unknown                 unknown
# 5                  LUNG EDEMA    unknown                 unknown
# 6                    AGITATED    unknown                 unknown
# 7          ABNORMAL MOVEMENTS    unknown                 unknown
# 8                    ACIDOSIS    0.43851                8.379133
# 9                    PELIOSIS    unknown                 unknown

# %%
# Convert 'Rank score' to numeric, setting errors='coerce' to turn non-numeric values into NaN
final_merged_df["Rank score"] = pd.to_numeric(final_merged_df["Rank score"], errors="coerce")

# Sort by 'Rank score', keeping NaNs (strings) at the bottom
final_merged_df = final_merged_df.sort_values(by="Rank score", ascending=False, na_position="last")

final_merged_df["Rank score"] = final_merged_df["Rank score"].fillna("unknown")
final_merged_df.to_csv('se_risks.csv', index=False)

# %% [markdown]
# univoc side effects

# %%
univoc_merged_df = final_merged_df.drop_duplicates(subset="Side_Effect_Name")
univoc_merged_df.to_csv('se_risks_univoc.csv', index=False)

# %% [markdown]
# unknown risk table

# %%
df_filtered = univoc_merged_df[univoc_merged_df.iloc[:, -2] == "unknown"]
df_filtered.to_csv('unknown_risk.csv', index=False)
